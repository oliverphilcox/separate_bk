# %%
import numpy as np
from bk_functions import *
import matplotlib.pyplot as plt

# %%
k_vals, bk = create_bk_dataset(grid_points=1000, func_name='bk_sl_collider', func_arg=None, kmin=0.01, kmax=1.0, n_points_k2=None, scale_invariant=True)
k_vals = k_vals.numpy()
bk = bk.numpy()
# bk = bk*bk # TEST FOR INNER PRODUCT
print(k_vals.shape, k_vals[-4:])
# Out:
# (255025, 3) [[0.998018   0.99999803 1.        ]
#  [0.999009   0.999009   1.        ]
#  [0.999009   0.999999   1.        ]
#  [1.         0.999999   1.        ]]

# %%
# k_vals[0:20],bk[0:20]

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

def plot_3d_data(xy_vals, bk, method='scatter', title='3D Plot'):
    """
    Plot 3D data with color mapping
    
    Args:
        k_vals: array of shape (N, 2) containing x and y coordinates
        bk: array of shape (N,) containing z values
        method: 'scatter' or 'surface'
        title: plot title
    """
    fig = plt.figure(figsize=(10, 8))
    ax = plt.axes(projection='3d')
    
    # Set viewing angle
    ax.azim = -75
    ax.dist = 10
    ax.elev = 30
    
    x = xy_vals[:, 0]
    y = xy_vals[:, 1]
    z = bk.flatten()
    
    if method == 'scatter':
        # Create scatter plot with color mapping
        scatter = ax.scatter3D(x, y, z, 
                             c=z,  # Color by z value
                             cmap='viridis',  # Choose colormap
                             s=30,  # Marker size
                             alpha=0.6)  # Transparency
        
        # Add colorbar
        fig.colorbar(scatter, ax=ax, label='Z Value')
        
    elif method == 'surface':
        # Create triangulation surface plot
        surf = ax.plot_trisurf(x, y, z,
                             cmap='viridis',
                             alpha=0.8)
        
        # Add colorbar
        fig.colorbar(surf, ax=ax, label='Z Value')
    
    # Labels and title
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title(title)
    
    # Set axis limits if needed
    # ax.set_xlim([x.min(), x.max()])
    # ax.set_ylim([y.min(), y.max()])
    # ax.set_zlim([z.min(), z.max()])
    
    plt.show()

# %%
fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axis

ax.azim = 50
ax.dist = 10
ax.elev = 20

x = k_vals[:,0]
y = k_vals[:,1]
z = bk.flatten()
c = z
# plotting
ax.plot3D(x, y, z)
plt.show()
# Out:
# /tmp/ipykernel_485111/1678281494.py:9: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 10

# %%
# Generate sample data
n_points = k_vals.shape[0]
x = k_vals[:,0]
y = k_vals[:,1]
z = bk.flatten()

xy_vals = np.column_stack((x, y))

# Create both types of plots
plot_3d_data(xy_vals, z, method='scatter', title='3D Scatter Plot with Color Mapping')
# Out:
# /tmp/ipykernel_485111/2907953055.py:20: MatplotlibDeprecationWarning: The dist attribute was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   ax.dist = 10

# %%
maxidx = np.where(bk==bk.max())[0]

# %%
k_vals[maxidx],
# kz note: the k-points generation seems to be a bit wrong
# Out:
# (array([[1., 1., 1.]], dtype=float32),)

# %%
print(bk_function_slow_collider_minus_eq(0.00001,1.1,1.2))
print(bk_function_slow_collider_minus_eq(1.1,1.2,1.3))
# Out:
# 0.0005852081625416486
# 1.0091806163892882
